# %% [markdown]
# <a href="https://colab.research.google.com/github/macedorafaelsilva/teste/blob/Alura/Gemini_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rodando IA no Google Colab

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('API_GEMINI_KEY')

# %%
from google import genai

client = genai.Client()

# %%
client.models.generate_content(model="gemini-2.5-flash", contents="o que é a inteligência artificial?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4292457173.py in <cell line: 0>()
# ----> 1 client.models.generate_content(model="gemini-2.5-flash", contents="o que é a inteligência artificial?")
#
# NameError: name 'client' is not defined
